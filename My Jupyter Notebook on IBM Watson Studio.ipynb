# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Name: Ivan Ferre Lo Castro**
#
# Industrial Engineer Student

# %% [markdown]
# *I am interested in data science because I am fascinated by the power of data to reveal insights and solve problems. With the explosion of data in today's world, data science is an exciting field that offers endless opportunities for learning and discovery.*

# %% [markdown]
# ### Code to Display the Sum of Two Numbers

# %%
a = 10
b = 5
sum = a + b
print("The sum of", a, "and", b, "is", sum)
# Out:
# The sum of 10 and 5 is 15

# %% [markdown]
# Here are some reasons why I enjoy using Jupyter Notebook:
#
# - It's a great tool for interactive computing and data exploration.
# - It supports multiple programming languages, including Python and R.
# - It allows me to easily document and share my code and results with others
#
# > Jupyter Notebook is an essential tool for anyone working with data.
#
#
#
#
# ![Logo de IBM](https://www.ibm.com/brand/identity/images/signet.svg)
